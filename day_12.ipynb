# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\cxash\Downloads\Student_Performance.csv")

# %%
dataset.head(10)   #it displays head rows
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
# 5              3               78                         No            9
# 6              7               73                        Yes            5
# 7              8               45                        Yes            4
# 8              5               77                         No            8
# 9              4               89                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# ...

# %%
dataset.shape  #it prints shape of dataset
# Out:
# (10000, 6)

# %%
dataset.isnull()  #checking null values in my dataset
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0             False            False                       False        False
# 1             False            False                       False        False
# 2             False            False                       False        False
# 3             False            False                       False        False
# 4             False            False                       False        False
# ...             ...              ...                         ...          ...
# 9995          False            False                       False        False
# 9996          False            False                       False        False
# 9997          False            False                       False        False
# 9998          False            False                       False        False
# 9999          False            False                       False        False
#
# ...

# %%
dataset.isnull().sum()  #it displays sum of null values - column-wise
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
dataset.isnull().sum().sum()  #it displays total null values from the dataset
# Out:
# np.int64(0)

# %%
dataset.shape[0]   #it displays shape (total) of rows
# Out:
# 10000

# %%
dataset.shape[1]    #it displys shape (total) of columns
# Out:
# 6

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1])*100)  #it calculates null values in dataset
# Out:
# np.float64(0.0)

# %%
(dataset.isnull().sum()/dataset.shape[0])*100  #it calculates percentage of null values column-wise
# Out:
# Hours Studied                       0.0
# Previous Scores                     0.0
# Extracurricular Activities          0.0
# Sleep Hours                         0.0
# Sample Question Papers Practiced    0.0
# Performance Index                   0.0
# dtype: float64

# %%
dataset.notnull()   #displaying not null or filled values in dataset
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              True             True                        True         True
# 1              True             True                        True         True
# 2              True             True                        True         True
# 3              True             True                        True         True
# 4              True             True                        True         True
# ...             ...              ...                         ...          ...
# 9995           True             True                        True         True
# 9996           True             True                        True         True
# 9997           True             True                        True         True
# 9998           True             True                        True         True
# 9999           True             True                        True         True
#
# ...

# %%
dataset.notnull().sum()   #displaying total no. of filled values column-wise
# Out:
# Hours Studied                       10000
# Previous Scores                     10000
# Extracurricular Activities          10000
# Sleep Hours                         10000
# Sample Question Papers Practiced    10000
# Performance Index                   10000
# dtype: int64

# %%
print(dataset.notnull().sum().sum())   #prints total filled values of dataset
# Out:
# 60000

# %%
#heatmap plotting
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns = ["Sleep Hours"], inplace = True)   #drops column in dataset - not really affects actual excel sheet

# %%
dataset.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  \
# 0              7               99                        Yes
# 1              4               82                         No
# 2              8               51                        Yes
# 3              5               52                        Yes
# 4              7               75                         No
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
dataset.shape
# Out:
# (10000, 5)

# %%
dataset.dropna(inplace = True)   #it drops all rows that contain null values

# %%
dataset.shape    #it gives same value becoz my dataset has no null values
# Out:
# (10000, 5)
