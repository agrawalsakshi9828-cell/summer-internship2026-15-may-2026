# %%
name = input("Enter your name: ")
student_class = input("Enter your class: ")
roll_no = input("Enter your roll number: ")
dob = input("Enter your date of birth: ")


print("\nStudent Details")
print("Name:", name)
print("Class:", student_class)
print("Roll Number:", roll_no)
print("Date of Birth:", dob)
# Out:
# Enter your name:  sakshi agrawal
# Enter your class:  ds ai and ml
# Enter your roll number:  35
# Enter your date of birth:  9 sep 2006
# Student Details
# Name: sakshi agrawal
# Class: ds ai and ml
# Roll Number: 35
# Date of Birth: 9 sep 2006

# %%
print("welcome to my python calculator")
print("""
1.addition
2.sub
3.mul
4.div
""")
a=int(input("enter your first number:" ))
print(a)
b=int(input("enter your second number: "))
print(b)
num=int(input("what do you want:"))
if num==1:
    print("addition")
    print(a+b)
elif num==2:
    print("sub")
    print(a-b)
elif num==3:
    print("mul")
    print(a*b)
elif num==4:
    print("div")
    print(a/b)
else:
    print("none")
# Out:
# welcome to my python calculator
#
# 1.addition
# 2.sub
# 3.mul
# 4.div
# enter your first number: 2
# 2
# enter your second number:  3
# 3
# what do you want: 2
# sub
# -1
