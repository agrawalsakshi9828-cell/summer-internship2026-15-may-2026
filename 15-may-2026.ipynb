# %%
print("hello python world")
# Out:
# hello python world

# %%
input("enter your name: ")
# Out:
# enter your name:  sakii
# 'sakii'

# %%
print("hello")
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %%
input("enter your name")
# Out:
# enter your name sakiii
# 'sakiii'

# %%
x=input("enter your name")
y=input("enter your class")
z=input("enter your roll number")
q=input("enter your dob")
print(x,y,z,q)
# Out:
# enter your name sakii
# enter your class ai
# enter your roll number 35
# enter your dob 9 sep 2026
# sakii ai 35 9 sep 2026

# %%
"""
sakii
hiii"""
# Out:
# '\nsakii\nhiii'

# %%
mobile_number=int(input("enter your mobile number:"))
# Out:
# enter your mobile number: 123456

# %%
print(mobile_number)
# Out:
# 123456
