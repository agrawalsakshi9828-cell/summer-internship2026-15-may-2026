# %%
import pandas as pd

# %%
df=pd.read_csv("Student_Performance.csv")

# %%
print(df)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.drop_duplicates(df)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["Hours Studied"],df["Performance Index"])
plt.xlabel("Hours Studied")
plt.ylabel("Performance Index")
plt.title("Hours StudiedvsPerformance Index")
plt.show()

# %%
plt.scatter(df["Previous Scores"],df["Performance Index"])
plt.xlabel("Previous Scores")
plt.ylabel("Performance Index")
plt.title("Previous ScoresvsPerformance Index")
plt.show()

# %%
plt.scatter(df["Sleep Hours"],df["Performance Index"])
plt.xlabel("Sleep Hours")
plt.ylabel("Performance Index")
plt.title("Sleep HoursvsPerformance Index")
plt.show()

# %%
plt.scatter(df["Sample Question Papers Practiced"],df["Performance Index"])
plt.xlabel("Sample Question Papers Practiced")
plt.ylabel("Performance Index")
plt.title("Sample Question Papers PracticedvsPerformance Index")
plt.savefig("graph_hp.jpeg")
plt.show()

# %%
#what is feature engineering??????/pdhna h brooooo
#yes  and noo problemm
#

# %%
plt.scatter(df["Sample Question Papers Practiced"],df["Hours Studied"])
plt.xlabel("Sample Question Papers Practiced")
plt.ylabel("Hours Studied")
plt.title("Sample Question Papers PracticedvsPerformance Index")
plt.savefig("graph_hp.jpeg")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  str
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), str(1)
# memory usage: 468.9 KB

# %%
# ismein dikkt  aa rhi h kii text smjh nhi pa rhaaa
#day11
#hrr ek feature ka weight mtlb kon kitna important h y=mx+c.... m ....konsi value kitni important h.....
#agr previous score mein missing hota koi row ya valuee to kya krna chahiyeee us row ko hta denge agr multiple rows missing h to uska avg ya mean nikal dengee
#to convert yes or no in 0 and 1 yes is 1 and 0 is no

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities              str
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
#feature ko check krke model mein fit krna is feature engineering
df["Extracurricular Activities"].unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
#yha apn ne string ko binary mein mtlb yes no ko 0,1 mein convert kiya h
df["Extracurricular Activities"]=df["Extracurricular Activities"].map({
    "Yes":1,
    "No":0
})

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
#agr future mein 3 values hui too 
city_df=pd.DataFrame({
    "city":["mumbai","pune","mumbai","jaipur"]

    
})

# %%
city_df
# Out:
#      city
# 0  mumbai
# 1    pune
# 2  mumbai
# 3  jaipur

# %%
pd.get_dummies(city_df)
# Out:
#    city_jaipur  city_mumbai  city_pune
# 0        False         True      False
# 1        False        False       True
# 2        False         True      False
# 3         True        False      False

# %%
pd.get_dummies(city_df,drop_first=True)
# Out:
#    city_mumbai  city_pune
# 0         True      False
# 1        False       True
# 2         True      False
# 3        False      False

# %%
x=df.drop("Performance Index",axis=1)

# %%
y=df["Performance Index"]

# %%
y.head()
# Out:
# 0    91.0
# 1    65.0
# 2    45.0
# 3    36.0
# 4    66.0
# Name: Performance Index, dtype: float64

# %%
#train or test mein split krna 
from sklearn.model_selection import train_test_split

# %%
x.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
# Out:
# (8000, 5)

# %%
print(y_train.shape)
# Out:
# (8000,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2.85248393, 1.0169882 , 0.60861668, 0.47694148, 0.19183144])

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([54.71185392, 22.61551294, 47.90314471, ..., 16.79341955,
#        63.34327368, 45.94262301], shape=(2000,))

# %%
#x train or y test ka graph bna ke compare krnaaa
comparison=pd.DataFrame({
    "Actual":y_test,
    "predicted":y_predict

    
})

# %%
comparison
# Out:
#       Actual  predicted
# 6252    51.0  54.711854
# 4684    20.0  22.615513
# 1731    46.0  47.903145
# 4742    28.0  31.289767
# 4521    41.0  43.004570
# ...      ...        ...
# 6412    45.0  46.886280
# 8285    66.0  62.698025
# 7853    16.0  16.793420
# 1095    65.0  63.343274
# 6929    47.0  45.942623
#
# [2000 rows x 2 columns]

# %%
#entire model ko train krr diya h 
#agr is model ko save krna h to joblib libraray se dump fucnction se
import joblib

# %%
joblib.dump(model,"Student_Performance.pkl")
# Out:
# ['Student_Performance.pkl']

# %%
joblib.load("Student_Performance.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 joblib.load("Student_Performance.pkl")
#
# NameError: name 'joblib' is not defined

# %%
#kaggle pe jao seach kro linear regression ka example or practice kroooo of linear regression or do eda data peakproceessing data cleaning krna h task h bhaii

# %%
#eda #niftyfifty   data set
#computer vision,nlp

# %%
df1=pd.read_csv("Walmart_Sales.csv")

# %%
print(df1)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df1.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df1.drop_duplicates(df1)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df1.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   str
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), str(1)
# memory usage: 402.3 KB

# %%
plt.scatter(df1["Weekly_Sales"],df1["Unemployment"])
plt.xlabel("Weekly_Sales")
plt.ylabel("Unemployment")
plt.title("Weekly_Sales vs Unemployment")
plt.show()

# %%
plt.scatter(df1["Holiday_Flag"],df1["Unemployment"])
plt.xlabel("Holiday_Flag")
plt.ylabel("Unemployment")
plt.title("Holiday_Flag vs Unemployment")
plt.show()

# %%
plt.scatter(df1["Temperature"],df1["Unemployment"])
plt.xlabel("Temperature")
plt.ylabel("Unemployment")
plt.title("Temperature vs Unemployment")
plt.show()

# %%
plt.scatter(df1["Fuel_Price"],df1["Unemployment"])
plt.xlabel("Fuel_Price")
plt.ylabel("Unemployment")
plt.title("Fuel_Price vs Unemployment")
plt.show()

# %%
df1.dtypes
# Out:
# Store             int64
# Date                str
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
df1["Date"].unique()
# Out:
# <StringArray>
# ['05-02-2010', '12-02-2010', '19-02-2010', '26-02-2010', '05-03-2010',
#  '12-03-2010', '19-03-2010', '26-03-2010', '02-04-2010', '09-04-2010',
#  ...
#  '24-08-2012', '31-08-2012', '07-09-2012', '14-09-2012', '21-09-2012',
#  '28-09-2012', '05-10-2012', '12-10-2012', '19-10-2012', '26-10-2012']
# Length: 143, dtype: str

# %%
pd.get_dummies(df1)
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
# ...

# %%
x=df1.drop("Weekly_Sales",axis=1)

# %%
print(df1.columns)
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='str')

# %%
y=df1["Weekly_Sales"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
# Out:
# (5148, 7)

# %%
print(y_train.shape)
# Out:
# (5148,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 model.fit(x_train,y_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_base.py:651, in LinearRegression.fit(self, X, y, sample_weight)
# ...

# %%
print(x_train.dtypes)
# Out:
# Store             int64
# Date                str
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
print(y_train.dtypes)
# Out:
# float64

# %%
#nhiii hoo rhaaa mujhseeeeeeee............

# %%
df1.shape
# Out:
# (6435, 8)

# %%
df1.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='str')

# %%
plt.scatter(df1["Holiday_Flag"],df1["Weekly_Sales"])
plt.xlabel("Holiday_Flag")
plt.ylabel("Weekly_Sales")
plt.title("Holiday_Flag vs Weekly_Sales")
plt.show()

# %%
plt.scatter(df1["Temperature"],df1["Weekly_Sales"])
plt.xlabel("Temperature")
plt.ylabel("Weekly_Sales")
plt.title("Temperature vs Weekly_Sales")
plt.show()

# %%
plt.scatter(df1["Fuel_Price"],df1["Weekly_Sales"])
plt.xlabel("Fuel_Price")
plt.ylabel("Weekly_Sales")
plt.title("Fuel_Price vs Weekly_Sales")
plt.show()

# %%
plt.scatter(df1["CPI"],df1["Weekly_Sales"])
plt.xlabel("CPI")
plt.ylabel("Weekly_Sales")
plt.title("CPI vs Weekly_Sales")
plt.show()

# %%
plt.scatter(df1["Unemployment"],df1["Weekly_Sales"])
plt.xlabel("Unemployment")
plt.ylabel("Weekly_Sales")
plt.title("Unemployment vs Weekly_Sales")
plt.show()

# %%
plt.scatter(df1["Store"],df1["Weekly_Sales"])
plt.xlabel("Store")
plt.ylabel("Weekly_Sales")
plt.title("Store vs Weekly_Sales")
plt.show()

# %%
plt.scatter(df1["Date"],df1["Weekly_Sales"])
plt.xlabel("Date")
plt.ylabel("Weekly_Sales")
plt.title("Date vs Weekly_Sales")
plt.show()

# %%
df1.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
#agr temp null hota h toooo....
#df["temperature"].isnull().sum()
#abb iska avg nukalengee mean taki wo nul values se replace hooo
#describe se bhi nikl chuka h woo
#df1["temperature"]=df1["temperature"].fillna(df1["temperature"].median)
#df1
#df1.isnull().sum()
#abb zero aayegaaa null h hi nhi fil krr chuke h median

# %%
d1=pd.to_datetime(df1["Date"],dayfirst=True)

# %%
d1
# Out:
# 0      2010-02-05
# 1      2010-02-12
# 2      2010-02-19
# 3      2010-02-26
# 4      2010-03-05
#           ...
# 6430   2012-09-28
# 6431   2012-10-05
# 6432   2012-10-12
# 6433   2012-10-19
# 6434   2012-10-26
# Name: Date, Length: 6435, dtype: datetime64[us]

# %%
plt.hist(
    df1["Weekly_Sales"],
    bins=10
    
    
)
plt.show()

# %%
plt.hist(
    df1["Temperature"],
    bins=10
    
    
)
plt.show()

# %%
plt.hist(
    df1["CPI"],
    bins=10
    
    
)
plt.show()

# %%
plt.hist(
    df1["Store"],
    bins=10
    
    
)
plt.show()

# %%
plt.hist(
    df1["Date"],
    bins=30
    
    
)
plt.show()

# %%
plt.hist(
    df1["Holiday_Flag"],
    bins=30
    
    
)
plt.show()

# %%
plt.hist(
    df1["Fuel_Price"],
    bins=30
    
    
)
plt.show()

# %%
plt.hist(
    df1["Unemployment"],
    bins=30
    
    
)
plt.show()

# %%
#store impactt krr rha h sales koo
#fule price bhi imapct krr rha h sales kooo
#jbb unemployment kbb sales zydaaa un zyda sales km
#date se koi corelation smjh hi nhiaa rhato apn date ko drop krr denge
#

# %%
ds=df1.drop("Date",axis=1,inplace=True)

# %%
df1
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment
# 0            8.106
# ...

# %%
y=df1["Weekly_Sales"]

# %%
from sklearn.model_selection  import train_test_split

# %%
from sklearn.linear_model  import LinearRegression

# %%
model=LinearRegression

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 model.fit(x_train,y_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
print(x_train.dtypes)
# Out:
# Store             int64
# Date                str
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object
