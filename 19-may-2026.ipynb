# %%
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
def mul(a,b):
    return a*b
def div(a,b):
    return a//b
def squareroot(a):
    return a**0.5

print("""
1.addition
2.subtraction
3.multiplication
4.division
5.squareroot
""")

choice=int(input("what is your choice:"))
print(choice)

a=int(input("enter your first number:"))
b=int(input("enter your first number:"))
if choice<=5:
    if choice==1:
        add(a,b)
    elif choice==2:
        sub(a,b)
    elif choice==3:
        mul(a,b)
    elif choice==4:
        div(a,b)
    elif choice==5:
        squareroot(a)
    else:
        print("bhai shi value daal de yrrr....")
else:
    print("tera dimag khrab h bhai")
# Out:
# 1.addition
# 2.subtraction
# 3.multiplication
# 4.division
# 5.squareroot
# what is your choice: 4
# 4
# enter your first number: 3
# enter your first number: 1

# %%
import tkinter
from tkinter import ttk
